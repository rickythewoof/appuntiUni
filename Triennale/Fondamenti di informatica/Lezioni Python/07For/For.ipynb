# %% [markdown]
# #### Autori: Domenico Lembo, Giuseppe Santucci and Marco Schaerf
#
# [Dipartimento di Ingegneria informatica, automatica e gestionale](https://www.diag.uniroma1.it)
#
# <img src="https://mirrors.creativecommons.org/presskit/buttons/88x31/png/by-nc-sa.eu.png"
#      alt="License"
#      style="float: left;"
#      height="40" width="100" />
# This notebook is distributed with license Creative Commons *CC BY-NC-SA*

# %% [markdown]
# # Ciclo For
# 1. Istruzione For
# 2. Funzione `range()`
# 3. Primi esempi di ciclo for
#     + 3.1. Esempio: uso for per stampa mesi dell'anno
#     + 3.2. Esempio: leggere stringa e calcolare la somma dei codici Unicode dei caratteri
# 4. Conversioni di base
#     + 4.1. Conversione da binario a decimale
#     + 4.2. Esempio: conversione da base 2-10 a base 10
# 5. Ciclo sui caratteri di una stringa (indice o carattere)
#     + 5.1. Esempio: stampa dei caratteri di una stringa in ordine inverso
# 6. Disegni di semplici figure geometriche
#     + 6.2. Esempio: Disegno di un quadrato pieno
#     + 6.3. Esempio: Disegno di un triangolo rettangolo isoscele
# 7. Doppi cicli
#     + 6.1. Esempio: Disegno di un quadrato pieno con un doppio ciclo
# 8. Differenze tra While e For
# 9. Esercizi

# %% [markdown]
# ### Istruzione For
# Python mette a disposizione un'altra istruzione di ciclo oltre al `while` per effettuare una ripetizione di istruzioni, l'istruzione `for`. La differenza fondamentale tra il `for` ed il `while` è che il `for` è più adatto quando dal contenuto corrente delle variabili in gioco è possibile sapere prima dell'esecuzione del ciclo quante ripetizioni del ciclo effettivamente faremo (cioè quando il ciclo è definito), mentre il `while` è più adatto quando non sappiamo il numero di ripetizioni.
#
# L'istruzione `for` ha la seguente struttura in Python, dove `i` è una variabile, detta variabile di ciclo. Il nome della variabile non è fisso, lo scegliamo noi:
#
# ```python
# for i in sequenza_di_valori:
#     istruzione1
#     istruzione2
#     ..
#     istruzionen
# ```
# L'esecuzione avviene nel seguente modo: La variabile `i` assume il primo valore della sequenza_di_valori e vengono eseguite tutte le istruzioni da 1 a n. Poi la variabile `i` assume il secondo valore della sequenza_di_valori e vengono eseguite tutte le istruzioni da 1 a n, e così via fino a che la `i` assume l'ultimo valore della sequenza_di_valori. A questo punto vengono eseguite un'ultima volta tutte le istruzioni da 1 a n ed il ciclo `for` termina.

# %% [markdown]
# ### Funzione `range()` ed elenchi valori
# Prima di vedere un'esempio di ciclo `for`, vediamo quali sono i modi più comuni di definire un insieme di valori da poter poi usare nel `for`. La funzione più frequentemente usata è la funzione `range()` che permette di generare insiemi di numeri. Se usiamo la funzione con un solo parametro  `n` (`range(n)`) essa genera l'insieme di tutti i numeri naturali da `0` (incluso) ad `n` (escluso). `range(n1,n2)` invece genera l'insieme di tutti i numeri naturali da `n1` (incluso) ad `n2` (escluso). Un'ultima variante prevede di specificare 3 parametri, in cui il primo è il valore iniziale (incluso), il secondo il valore finale (escluso) ed il terzo è il passo (step) usato per andare dal valore inziale a quello finale.
#
# L'insieme dei valori in Python può anche essere una stringa oppure essere esplicitamente indicato con la notazione `[valore1, valore2, valore3, ... valoren]`. Questa in Python si chiama lista e la vedremo in dettaglio più avanti nel corso. Ci sono anche altri modi in Python di denotare un insieme o sequenze di valori. Anche questi li vedremo più avanti nel corso.
#
# Per visualizzare in modo più intuitivo la sequenza di valori generata dalla funzione `range()` la convertiremo in una lista con la funzione `list()`

# %%
print(range(5))
print(list(range(5)))
print(list(range(2,7)))
print(list(range(2,9,2)))
x = [2, 3, 5 , 'casa']
print(x)
print(list(range(9,2,-1)))

# %% [markdown]
# ### Primi esempi di ciclo for
# Vediamo ora alcuni esempi per capire come usare il ciclo `for` su diversi insiemi di valori

# %%
for i in range(5):
    print(i)

print()
    
s="pasta"

for i in range(len(s)):
    print(s[i])

print()    
    
for c in s:
    print(c)

print()    
    
for i in [4,6,'casa',9,81]:
    print(i)

# %% [markdown]
# #### Esempio: uso for per stampa mesi dell'anno

# %%
for s in ["gennaio", "febbraio", "marzo", "aprile","maggio",
          "giugno","luglio","agosto","settembre","ottobre",
          "novembre","dicembre"]:
    print(s)

# %% [markdown]
# #### Esempio: leggere stringa e calcolare la somma dei codici Unicode dei caratteri

# %%
s=input("inserisci una stringa: ")
somma=0
for i in range(len(s)):
    somma=somma+ord(s[i])
    print(s[i],ord(s[i]))
print("somma=",somma)

# %% [markdown]
# ### Conversioni di base

# %% [markdown]
# #### Conversione da binario a decimale
# Il seguente programma legge una stringa composta dai caratteri '0' e '1' e calcola il numero decimale corrispondente

# %%
s=input("inserisci una stringa corrispondente a un binario: ")
valore=0
potenza=len(s)-1
for c in s:
    valore=valore+int(c)*2**potenza
    potenza=potenza-1
print(s,"vale",valore)

# %% [markdown]
# #### Esempio: conversione da base 2-16 a base 10
# Scrivere un programma che prende in input una base (tra 2 e 16) ed un numerale in quella base e restituisce il numero decimale corrispondente. Usare il ciclo while per ripetere il programma.

# %%
finito=False
while not finito:
    
    #-----------
    base=int(input("inserisci la base (2..16): "))
    s=input("inserisci un numerale in base "+str(base)+": ")
    valore=0
    potenza=len(s)-1
    for c in s:
        if c in "ABCDEF":
            valore=valore+(ord(c)-ord("A")+10)*base**potenza
        else:    
            valore=valore+int(c)*base**potenza
        potenza=potenza-1
    print(s,"vale",valore)
    #------------
    s1=input("----Finisco (si/no)? ")
    finito=s1.lower()=="si"

# %% [markdown]
# ### Ciclo sui caratteri di una stringa (indice o carattere)
# Come abbiamo già visto, è possibile effettuare un ciclo `for` che scandisce tutti i caratteri di una stringa in 2 modi diversi, con un ciclo sugli indici oppure con un ciclo sui caratteri. Vediamo differenze, vantaggi e svantaggi delle 2 soluzioni.
#
# Vantaggi del ciclo sui caratteri:
# 1. Codice più semplice ed immediato
# 2. Accesso diretto ai caratteri
#
# Svantaggi:
# 1. Non conoscenza della posizione dei caratteri
# 2. Difficoltà a scandire in ordine diverso da quello standard

# %%
#scansione stringa tramite accesso diretto ai suoi elementi
#ovvero la stringa è una "sequenza" di caratteri
s=input("Inserisci una stringa: ")

for c in s:
    print(c,"=",ord(c))

print()
    
for i in range(len(s)):
    print(s[i],"=",ord(s[i]))

# %% [markdown]
# #### Esempio: stampa dei caratteri di una stringa in ordine inverso
# Scrivere un programma che legge una stringa e stampa i suoi caratteri in ordine inverso

# %%
#stampa dei caratteri di una stringa in ordine inverso
#tramite indice. 
s=input('Inserisci la stringa: ')

for i in range(len(s)-1,-1,-1):
#genera l'insieme dei valori da len(s) - 1 fino a 0 (-1 escluso)
#in ordine decrescente (con passo -1)
    print(s[i])

print()
    
# se scandiamo i caratteri di una stringa, non possiamo in effetti 
# cambiare l'ordine di scansione, come invece fatto usando gli indici. 
# In questo esempio, comunque potremmo prima invertire la stringa 
# per poi scandirla successivamente. Ciò non toglie che la scansione 
# tramite indici ci offre maggiore flessibilità

for c in s[::-1]:
    print(c)

# %% [markdown]
# ### Disegni di semplici figure geometriche

# %% [markdown]
# #### Esempio: Disegno di un quadrato pieno
# Scrivere un programma che prende in input un numero positivo n e stampa sullo schermo un quadrato di lato n di caratteri $*$

# %%
#stampa quadrato
l=int(input("inserisci lato del quadrato: "))

for i in range(l):
    print("*"*l)
    
# versione senza uso del ciclo
# print(('*'*l+'\n')*l)

# %% [markdown]
# #### Esempio: disegno triangolo rettangolo isoscele
# Scrivere un programma che prende in input un numero positivo n e stampa sullo schermo un triangolo rettangolo isoscele con i cateti di lunghezza n e riempito con il carattere $*$

# %%
#stampa triangolo rettangolo isoscele
ct=int(input("inserisci lunghezza dei cateti: "))

for i in range(ct):  
    print("*"*(i+1))

# %% [markdown]
# ### Cicli annidati
# In molte situazioni abbiamo bisogno che un'istruzione di ciclo (`while` o `for`) venga a sua volta ripetuta più volte. Questo è chiaramente possibile ed in questo caso si parla di cicli annidati. Si possono annidare i cicli quante volte si vuole ed i cicli possono essere di tipi diversi, ad esempio un ciclo `while` può essere annidato all'interno di un ciclo `for` o un ciclo `for` può essere annidato all'interno di un ciclo `while` (notate che un primo esempio di ciclo (for) annidato (in un while) lo abbiamo visto per la conversione da base 2-16 a base 10). Vediamo ora come esempio la stampa a schermo della tabellina delle moltiplicazioni dei numeri da 1 a 10.

# %%
for i in range(1,11):
    for j in range(1,11):
        print(i*j, end='\t') # In questo modo, dopo aver stampato un numero invece di andare a riga nuova inserisce un tab ('\t')
    print() # Dopo aver completato ogni ciclo della variabile j va a riga nuova

# %% [markdown]
# #### Esempio: Disegno di un quadrato pieno con un doppio ciclo
# Risolviamo l'esercizio visto in precedenza usando un doppio ciclo for, in cui ad ogni passo stampiamo un solo carattere

# %%
#stampa quadrato
l=int(input("inserisci lato del quadrato: "))

for i in range(l):
    for j in range(l):
        print("*",end='') # Dopo aver stampato un carattere non va a riga nuova ma continua di seguito (inserisce una stringa vuota)
    print() # Dopo aver completato una riga va a riga nuova

# %% [markdown]
# ### Differenze tra While e For
# Nella maggior parte dei problemi che ci troviamo a risolvere, si possono utilizzare sia il ciclo `while` che il ciclo `for`, ci sono però importanti differenze che possono far prediligere l'uno o l'altro. Il ciclo `for` è tipicamente più compatto ed efficiente, ma meno generale. Il ciclo `while` è più adatto nelle seguenti situazioni:
# 1. Non c'è una variabile che assume un insieme di valori
# 2. Non è noto a priori l'insieme dei valori da assumere
# 3. Non tutti i valori dell'insieme devono essere necessariamente analizzati (vedremo come si possono trattare questi casi con il `for` nel prossimo notebook, ma spesso il while rimane preferibile)
# 4. L'insieme di valori da assumere cambia durante l'esecuzione
#
# Esempi della situazione 1 sono nel Notebook sul While, e sono il programma *Esempio di uso del while per ripetere un programma*, oppure *Esempio di generazione di stringa casuale che termina per "o"* mentre esempi del caso 2 sono i programmi che fanno uso di un valore sentinella per terminare l'inserimento di una sequenza di dati in input. Queste situazioni si riferiscono in effetti sempre a cicli indefiniti, che non possono essere risolti con l'uso del `for`. Per ora non abbiamo visto esempi della situazione 4, ma ci torneremo quando vedremo altri tipi di dati come, ad esempio, le liste.
#
# Esempi del tipo 3 sono i programmi della sezione *Ricerca di valori caratteristici di una sequenza o insieme* nel notebook su accumularori, ma vediamo ora un esempio di questo tipo (controllo se un numero sia primo) risolto sia con il `while` che con il `for` (2 versioni con il `for`, di cui la prima non è precisa).

# %%
#Verifica che un numero sia primo, con il ciclo while 
#si assuma un input maggiore di 1

n = int(input("Inserire un numero naturale maggiore di 1: "))

i = 2 #cerco un divisore, partendo da 2
limite = n-1 #massimo numero da considerare per verificare se c'è un divisore

while i <= limite and n%i != 0: #finchè non ho raggiunto il limite e non ho trovato un divisore
    i += 1 #vado a provare il prossimo divisore
if i >= limite: #non ho trovato un divisore
    print('numero primo')
else:
    print('numero non primo')

# %%
#Verifica che un numero sia primo, con il ciclo for (prima versione)

n = int(input('Inserire il numero da verificare se sia primo: '))

limite = n-1 #massimo numero da considerare per verificare se c'è un divisore

for i in range(2,limite+1):
    if n%i == 0: #ho trovato un divisore
        print('numero non primo')
if i >= limite:
    print('numero primo')

# %% [markdown]
# #### Difficoltà con il for
# Il programma proposto riesce ad identificare se c'è un divisore, ma non riesce a fermarsi immediatamente, inoltre il valore della variabile `i` non è chiaramente definito al di fuori del ciclo. Per ovviare a questo problema, dobbiamo introdurre un ulteriore controllo e variabile booleana.

# %%
#Verifica che un numero sia primo, con il ciclo for (seconda versione)

n = int(input('Inserire il numero da verificare se sia primo: '))

limite = n-1 #massimo numero da considerare per verificare se c'è un divisore
trovatodivisore = False

for i in range(2,limite+1):
    if n%i == 0 and not trovatodivisore: # falso se ho già trovato un divisore (che è anche il primo)
        print('numero non primo')
        trovatodivisore = True
if not trovatodivisore:
    print('numero primo')

# %% [markdown]
# ### Esercizi
# Completate questi esercizi prima di cominciare il prossimo argomento

# %% [markdown]
# ### Esercizio 1:
# Scrivere un programma che calcola la somma dei primi m termini della serie armonica, per un dato valore di m letto da input. Si ricorda che la serie armonica ha la seguente formula $\displaystyle\sum_{k=1}^m 1/k$

# %% [markdown]
# ### Esercizio 2:
# Scrivere un programma Python che stampa a schermo la tabellina di un numero compreso fra 1 e 10 inserito in input dall'utente. Ad esempio, se il numero inserito è 4, il programma deve stampare
#
# 4 x 1 = 4<br>
# 4 x 2 = 8<br>
# 4 x 3 = 12<br>
# ...

# %% [markdown]
# ### Esercizio 3:
# Scrivere un programma che calcoli il valore di un polinomio di grado qualsiasi, $a_nx^n + a_{n-1}x^{n−1} + . . . + a_1 x + a_0$, per un dato valore della variabile $x$. Il programma legge da tastiera il grado del polinomio, il valore di $x$, e i valori dei coefficienti, richiesti all'utente uno alla volta.
#
# *Suggerimento*: scrivere un ciclo che chiede un coefficiente alla volta a partire dal termine di grado inferiore ($a_0$) e calcola il risultato parziale del valore del polinomio, accumulandolo in una variabile (che viene incrementata ad ogni iterazione).

# %% [markdown]
# ### Esercizio 4:
# Scrivere un programma che legge da tastiera un numero in base 2, lo converte in base 8 e stampa a schermo il risultato

# %%
# Si ricorda che per convertire un numero n da base 2 a base 8 
# si divide n in gruppi da 3 cifre e si converte ogni gruppo
# separatemente. Se in numero non ha un numero di cifre divisibile per 3
# si aggiungono degli 0 iniziali, fino ad arrivare ad un numero 
# di cifre divisibile per 3

# %% [markdown]
# ### Esercizio 5:
# Scrivere un programma che legge una stringa e trova il carattere della stringa il cui codice Unicode sia minimo e lo stampa a schermo. Fornire una soluzione sia con ciclo sui caratteri che sulle posizioni

# %% [markdown]
# ### Esercizio 6:
# Scrivere un programma che stampa di seguito più quadrati di caratteri $*$, ognuno con la sua dimensione letta da input. Il programma deve terminare quando viene inserito come dimensione il valore 0 (in altri termini, il programma acquisisce ripetutamente da input la dimensione n e stampa il quadrato di dimensione n. Se n=0, il programma termina)
